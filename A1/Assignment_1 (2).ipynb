# %%
import torch

# Torch (and PyTorch) PyTorch is one of the most popular frameworks for
#  developing and training machine learning and deep learning models.

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# CUDA (Compute Unified Device Architecture) is a parallel computing platform
# and programming model developed by NVIDIA for their GPUs. CUDA harness the
# highly parallel processing power of GPUs to perform general-purpose computing
# tasks (i.e., tasks beyond traditional graphics rendering).
# Out:
# Using device: cuda

# %%
from diffusers import DiffusionPipeline

# switch to "mps" for apple devices
pipe = DiffusionPipeline.from_pretrained("ItsJayQz/GTA5_Artwork_Diffusion",
                                         dtype=torch.bfloat16, device_map="cuda")

#pipe = DiffusionPipeline.from_pretrained("8clabs/sketch-model-1", dtype=torch.bfloat16, device_map="cuda")
#pipe = DiffusionPipeline.from_pretrained("tensor-diffusion/LEOSAMs-HelloWorld-Grain2", dtype=torch.bfloat16, device_map="cuda")
#pipe = DiffusionPipeline.from_pretrained("prompthero/openjourney", dtype=torch.bfloat16, device_map="cuda")

#pipe = DiffusionPipeline.from_pretrained("baqar11092/StableDiffusionDreamBooth", dtype=torch.bfloat16, device_map="cuda")
#pipe = DiffusionPipeline.from_pretrained("gpustack/stable-diffusion-xl-inpainting-1.0-GGUF", dtype=torch.bfloat16, device_map="cuda")
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# ...

# %%
# We can also use other diffusion models, for example stable diffusion, hosted
# by RunwayML on HuggingFace
from diffusers import DiffusionPipeline

model_id = "segmind/tiny-sd"  # or any other compatible model
# model_id = "stabilityai/sdxl-turbo"
pipe = DiffusionPipeline.from_pretrained(model_id,
                                         dtype=torch.bfloat16, device_map="cuda")
# Out:
# model_index.json:   0%|          | 0.00/584 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/691 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/755 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/722 [00:00<?, ?B/s]
# text_encoder/pytorch_model.bin:   0%|          | 0.00/246M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/759 [00:00<?, ?B/s]
# unet/diffusion_pytorch_model.bin:   0%|          | 0.00/647M [00:00<?, ?B/s]
# vae/diffusion_pytorch_model.bin:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Keyword arguments {'dtype': torch.bfloat16} are not expected by StableDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# ...

# %%
# We can also use other diffusion models, for example stable diffusion, hosted
# by RunwayML on HuggingFace
from diffusers import DiffusionPipeline

model_id = "ziyu600601/jkadshksfjee"  # or any other compatible model
# model_id = "stabilityai/sdxl-turbo"
pipe = DiffusionPipeline.from_pretrained(model_id,
                                         dtype=torch.bfloat16, device_map="cuda")
# Out:
# model_index.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# text_encoder/pytorch_model.bin:   0%|          | 0.00/492M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/748 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# unet/diffusion_pytorch_model.bin:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# vae/diffusion_pytorch_model.bin:   0%|          | 0.00/335M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# Keyword arguments {'dtype': torch.bfloat16} are not expected by StableDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# ...

# %%
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained(
    "Lykon/dreamshaper-8",
     #"stabilityai/sd-turbo",
    torch_dtype=torch.float16,
    variant="fp16",
    ).to(device)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# CLIPFeatureExtractor appears to have been deprecated in transformers. Using CLIPImageProcessor instead.

# %%
# Define your prompt
#prompt = "Surreal collage composition of a jewelry display bust transformed into a fragile body, marble surface covered with dark veins running from the neck down the torso like a necklace pattern, several open cracks in the bust inspired by Frida Kahlo’s The Broken Column, stitched with thin metallic needles, layered with torn fabric fragments collaged onto the surface, surreal museum lighting, hanging lamps above casting string-like rays that fall to the floor like glowing lava fissures, dada and surrealist photomontage style, poetic, symbolic, humorous, highly detailed."
#prompt = "Surreal collage style scene of a lonely office worker sitting at a desk in a quiet 1950s office, but the worker's head is replaced by a metal filing cabinet, drawers slightly open with papers floating out, absurd and poetic, soft cinematic lighting, vintage surrealism, hannah hoch inspired, dreamlike, detailed, humorous symbolism."
#prompt = "A jewelry chest bust that features a pattern of veins running from around the neck to down the bust, resembling a necklace piece. These veines i would like to have some open cracks, similar to Friday Khalo’s broken column. Please add some fabric and pieces of needles, i also would like to have some lamps on the upper part of the image, with string rays beaming down in a way that elicits some lava crack on the floor."
#prompt = "Surreal collage style scene of the same office worker sitting at the same desk in a quiet 1950s office, now the worker’s head and torso are transformed into stacked filing cabinets, drawers opening, documents spilling like thoughts, absurd poetic logic, soft cinematic lighting, vintage surrealism, hannah hoch inspired, dreamlike, detailed, humorous symbolism."
#prompt = "1920s surreal photomontage collage, cut-and-paste composition of a jewelry display bust treated like a human torso, flat paper texture, visible torn magazine edges, mismatched scale, marble skin covered with dark vein patterns forming a necklace, large open cracks inspired by The Broken Column, stitched with thin sewing needles, layered fabric scraps glued onto the surface, absurd museum stage made from pasted fragments, hanging desk lamps cut out from magazines, harsh graphic light rays drawn like strings falling onto the floor as lava-like paper fissures, Hannah Höch, Max Ernst collage logic, dadaist, surreal, awkward, symbolic"
#prompt = "1920s dadaist surreal paper collage print, awkward cut-and-glue composition, scanned artifact with paper grain and misregistered ink, the same jewelry bust figure fragmented into cubist and futurist shards, vein-necklace pattern breaking the frame, cracked marble paper body with poetic openings, sewing needles embedded like printed ornaments, ripped fabric pieces layered over magazine fragments, exaggerated lamps and flat string light beams collaged across the page, distorted scale, visible glue seams, poster-like graphic style, Hannah Höch and Max Ernst inspired photomontage aesthetic, symbolic, absurd, not painterly."
#prompt = "Scanned 1920s surreal paper collage artwork, photomontage made from cut magazine and encyclopedia prints, flat graphic style, visible torn paper edges and glue seams, mismatched scale, awkward composition, a jewelry display bust treated like a human torso, printed marble texture with dark vein shapes forming a necklace, large cracked openings inspired by Frida Kahlo’s Broken Column, stitched with illustrated sewing needles, fabric scraps pasted onto the paper surface, absurd museum stage built from glued fragments, desk lamps cut from old catalog prints, harsh graphic string-like light rays drawn in ink falling onto the floor as lava-shaped paper fissures, halftone texture, aged paper grain, symbolic, dada and surrealist collage logic."
#prompt = "Surreal vintage newspaper collage in the style of Hannah Höch and Max Ernst, dada photomontage. A bureaucratic dream office built from torn newspaper fragments and old engravings. A human body with a filing cabinet for a head sits at a tiny desk, while giant floating eyes watch from the ceiling. Fish swim through the air between paper walls. Cut-and-paste aesthetic, aged paper texture, halftone print, visible glue marks, ironic surreal logic, symbolic pairing, awkward composition, 1920s avant-garde collage."
#prompt = "A highly detailed surreal collage integrated into an antique oil painting landscape. The scene shows a wide classical countryside with small stone houses clustered in a quiet village at the base of soft blue mountains, under a cloudy faded sky. The painting surface shows cracked varnish, aged canvas texture, muted baroque color tones, and visible brush strokes.In the foreground, two villagers stand as if posing for a portrait inside the landscape. The woman wears a long painted dress, but the center of her body is replaced by a realistic glass hourglass filled with sand, carefully pasted into her torso with visible glued paper edges. Her head, arms, and legs remain traditionally painted. Beside her, a man in old village clothing has surreal collage modifications: thin black clock hands replace his eyebrows and curl into a small mustache shape across his face. The same clock hands replace his fingers on both hands. The hands are cut-paper collage elements layered on top of the painted body. The collage anatomy contrasts with the serious old painting style, creating a strange, comedic, and uncanny interruption of a peaceful historical landscape."
#prompt = "Foreground portrait of two full-body villagers standing in the center of the image, clearly visible and dominant in the composition. The woman and man are the main focus. The woman wears a long painted village dress, but the middle of her torso is replaced by a large transparent glass hourglass filled with flowing sand. The hourglass is embedded into her body like a cut-paper collage, with rough scissor edges and visible glued seams where paint meets paper. Her head, arms, and legs remain traditionally painted. Next to her, the man wears old rural clothing. Thin black clock hands replace his eyebrows and form a curled mustache across his face. The same clock hands replace all his fingers, stiff and mechanical. These are pasted collage elements layered on top of the painted skin. The scene is styled as an antique oil painting on aged canvas with cracked varnish, muted classical colors, visible brush strokes, and faded pigments. Behind the couple, a peaceful mountain village landscape appears: small stone houses, winding paths, rolling hills, and distant blue-gray mountains under a cloudy sky."
#prompt = "((two villagers in the foreground:1.6)), full body portrait, antique oil painting style, aged canvas, cracked varnish. Woman with ((printer machine torso instead of human chest and stomach:1.9)), surreal collage anatomy, glued paper edges. Man with ((desk lamp head instead of human head:1.9)), absurd body replacement. Both villagers have ((stapler and keyboard key fingers:1.9)), mechanical collage hands. Background: peaceful mountain village landscape, small stone houses, hills, distant mountains, cloudy sky, muted classical colors."

#assigment prompt variation

#prompt = "Surreal Dadaist collage scene of an office worker sitting at a 1950s office desk, the worker's face replaced with a giant clock, fishbowl floating on the water dispenser, office papers slowly turning into tiny birds flying away, absurd and whimsical, dreamlike, humorous, inspired by Hannah Höch and Max Ernst, collage style, chaotic but visually balanced, detailed, soft cinematic lighting"
#prompt = "Surreal Dadaist collage of an office worker at a desk, torso replaced with filing cabinets spilling papers that transform into birds, office chair wheels replaced by teapots, floating pencils and coffee cups, absurd dream logic, whimsical and humorous, inspired by Dadaism and surrealist collage, chaotic but detailed, cinematic lighting"
#prompt = "Surreal Dadaist collage of an office scene, worker fully merging with office furniture, drawers and chairs growing from body, floating clocks, fishbowls, papers, and coffee cups hovering in mid-air, absurd, playful, dreamlike, whimsical, inspired by Max Ernst and Hannah Höch, collage style, detailed and chaotic, cinematic soft lighting"


# Generate and save the image
#image = pipe(prompt).images[0]
#image
#negative_prompt = "normal anatomy, realistic hands, portrait photography, cinematic lighting, fantasy art, game art, smooth digital painting"

image = pipe(
    prompt,
    #negative_prompt=negative_prompt,
    guidance_scale=8.5,
    num_inference_steps=45,
    height=768,
    width=512
).images[0]

# If instead of displaying the resulting media object we want to save it to the
# Linux machine where you are running your code, you can do:
image.save("output_image.png")
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# You can check and navigate the mounted path by
# !ls /content/drive/MyDrive/
# Out:
#  cart346-Gauthier-a01   Disney		        stuff
#  Cart498	        Light_Painting_images  'Untitled_Artwork 6.png'
# 'Colab Notebooks'       Old		       'Untitled document.gdoc'
